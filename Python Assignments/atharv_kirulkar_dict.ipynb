# %%
# Python Dictionary Assignment
# 1. Create a dictionary with 5 students and their marks.
# 2. Print the value of a specific student using their name as key.
# 3. Add a new student with marks to the dictionary.
# 4. Update the marks of an existing student.
# 5. Delete a student from the dictionary.
# 6. Print all student names using keys().
# 7. Print all student marks using values().
# 8. Print all student names with their marks using items().
# 9. Check if a specific student is in the dictionary.
# 10. Check if a specific mark is present in the dictionary values.
# 11. Use get() to fetch a student's marks safely.
# 12. Create a dictionary of employees with their departments.
# 13. Access the department of a specific employee.
# 14. Add a new employee and department.
# 15. Change the department of an existing employee.
# 16. Remove an employee from the dictionary.
# 17. Sort the employee dictionary by employee names in ascending order.
# 18. Sort the employee dictionary by department names in ascending order.
# 19. Sort the employee dictionary by names in descending order.
# 20. Sort the employee dictionary by department in descending order.
# 21. Find all keys that have a specific value in a dictionary.
# 22. Count how many students scored above 80 marks.
# 23. Create a nested dictionary for 3 students with age, grade, and department.
# 24. Access the grade of a student from the nested dictionary.
# 25. Update the department of a student in the nested dictionary.
# 26. Loop through the nested dictionary and print student names with their grades.
# 27. Merge two dictionaries of students into one.
# 28. Clear all entries in a dictionary.
# 29. Copy a dictionary into a new dictionary and modify the copy.
# 30. Create a dictionary where keys are numbers 1-5 and values are their squares.

# %%
# 1. Create a dictionary with 5 students and their marks.
students = {"Alice":22,"Bob":19,"Charlie":30,"David":15,"Peter":25}
print(students)
# Out:
# {'Alice': 22, 'Bob': 19, 'Charlie': 30, 'David': 15, 'Peter': 25}

# %%
# 2. Print the value of a specific student using their name as key.
print(students["Bob"])
# Out:
# 19

# %%
# 3. Add a new student with marks to the dictionary.
students["Annie"] = 27
print(students)
# Out:
# {'Alice': 22, 'Bob': 19, 'Charlie': 30, 'David': 15, 'Peter': 25, 'Annie': 27}

# %%
# 4. Update the marks of an existing student.
students["Annie"] = 21
print(students)
# Out:
# {'Alice': 22, 'Bob': 19, 'Charlie': 30, 'David': 15, 'Peter': 25, 'Annie': 21}

# %%
# 5. Delete a student from the dictionary.
del students["David"]
print(students)
# Out:
# {'Alice': 22, 'Bob': 19, 'Charlie': 30, 'Peter': 25, 'Annie': 21}

# %%
# 6. Print all student names using keys().
for name in students.keys():
    print(name)
# Out:
# Alice
# Bob
# Charlie
# Peter
# Annie

# %%
# 7. Print all student marks using values().
for marks in students.values():
    print(marks)
# Out:
# 22
# 19
# 30
# 25
# 21

# %%
# 8. Print all student names with their marks using items().
print("Name\tMarks")
for name, marks in students.items():
    print(name,"\t",marks)
# Out:
# Name	Marks
# Alice 	 22
# Bob 	 19
# Charlie 	 30
# Peter 	 25
# Annie 	 21

# %%
# 9. Check if a specific student is in the dictionary.
print("David" in students.keys())
# Out:
# False

# %%
# 10. Check if a specific mark is present in the dictionary values.
print(30 in students.values())
# Out:
# True

# %%
# 11. Use get() to fetch a student's marks safely.
alice_marks = students.get("Charlie")
print(alice_marks)
# Out:
# 30

# %%
# 12. Create a dictionary of employees with their departments.
employees = {"Alice":"Sales","Bob":"HR","Charlie":"Design","David":"Marketing"}
print(employees)
# Out:
# {'Alice': 'Sales', 'Bob': 'HR', 'Charlie': 'Design', 'David': 'Marketing'}

# %%
# 13. Access the department of a specific employee.
print(employees["Alice"])
# Out:
# Sales

# %%
# 14. Add a new employee and department.
employees["Peter"] = "HR"
print(employees)
# Out:
# {'Alice': 'Sales', 'Bob': 'HR', 'Charlie': 'Design', 'David': 'Marketing', 'Peter': 'HR'}

# %%
# 15. Change the department of an existing employee.
employees["Bob"] = "Security"
print(employees)
# Out:
# {'Alice': 'Sales', 'Bob': 'Security', 'Charlie': 'Design', 'David': 'Marketing', 'Peter': 'HR'}

# %%
# 16. Remove an employee from the dictionary.
del employees["David"]
print(employees)
# Out:
# {'Alice': 'Sales', 'Bob': 'Security', 'Charlie': 'Design', 'Peter': 'HR'}

# %%
# 17. Sort the employee dictionary by employee names in ascending order.
sorted_employees = dict(sorted(employees.items()))
print(sorted_employees)
# Out:
# {'Alice': 'Sales', 'Bob': 'Security', 'Charlie': 'Design', 'Peter': 'HR'}

# %%
# 18. Sort the employee dictionary by department names in ascending order.
sorted_employees = dict(sorted(employees.items(),key = lambda x : x[1]))
print(sorted_employees)
# Out:
# {'Charlie': 'Design', 'Peter': 'HR', 'Alice': 'Sales', 'Bob': 'Security'}

# %%
# 19. Sort the employee dictionary by names in descending order.
sorted_employees = dict(sorted(employees.items(),reverse=True))
print(sorted_employees)
# Out:
# {'Peter': 'HR', 'Charlie': 'Design', 'Bob': 'Security', 'Alice': 'Sales'}

# %%
# 20. Sort the employee dictionary by department in descending order.
sorted_employees = dict(sorted(employees.items(),key = lambda x : x[1],reverse = True))
print(sorted_employees)
# Out:
# {'Bob': 'Security', 'Alice': 'Sales', 'Peter': 'HR', 'Charlie': 'Design'}

# %%
# 21. Find all keys that have a specific value in a dictionary.
search_value = 'Security'
keys = [key for key, value in employees.items() if value == search_value ]
print(keys)
# Out:
# ['Bob']

# %%
# 22. Count how many students scored above 80 marks.
students = {"Alice":82,"Bob":79,"Charlie":100,"David":65,"Peter":95}
count = 0
for value in students.values():
    if value > 80:
        count+=1
print(count)
# Out:
# 3

# %%
# 23. Create a nested dictionary for 3 students with age, grade, and department.
students = {"Alice":{'age':19,'grade':'A+','department':'IT'},
            "Bob":{'age':20,'grade':'A','department':'ECE'},
            "Charlie":{'age':19,'grade':'B+','department':'MECH'}}
print(students)
# Out:
# {'Alice': {'age': 19, 'grade': 'A+', 'department': 'IT'}, 'Bob': {'age': 20, 'grade': 'A', 'department': 'ECE'}, 'Charlie': {'age': 19, 'grade': 'B+', 'department': 'MECH'}}

# %%
# 24. Access the grade of a student from the nested dictionary.
print(students["Alice"]["grade"])
# Out:
# A+

# %%
# 25. Update the department of a student in the nested dictionary.
students["Alice"]["department"] = 'CS'
print(students)
# Out:
# {'Alice': {'age': 19, 'grade': 'A+', 'department': 'CS'}, 'Bob': {'age': 20, 'grade': 'A', 'department': 'ECE'}, 'Charlie': {'age': 19, 'grade': 'B+', 'department': 'MECH'}}

# %%
# 26. Loop through the nested dictionary and print student names with their grades.
print("Name\tGrades")
for key, value in students.items():
    print(key,"\t",value["grade"])
# Out:
# Name	Grades
# Alice 	 A+
# Bob 	 A
# Charlie 	 B+

# %%
# 27. Merge two dictionaries of students into one.
students_1 = {"Alice":82,"Bob":79}
students_2 = {"Charlie":100,"David":65,"Peter":95}

students = students_1 | students_2
print(students)
# Out:
# {'Alice': 82, 'Bob': 79, 'Charlie': 100, 'David': 65, 'Peter': 95}

# %%
# 28. Clear all entries in a dictionary.
students.clear()
print(students)
# Out:
# {}

# %%
# 29. Copy a dictionary into a new dictionary and modify the copy.
students = {"Alice":82,"Bob":79,"Charlie":100,"David":65,"Peter":95}
students_copy = students.copy()
del students_copy["David"]
print(students)
print(students_copy)
# Out:
# {'Alice': 82, 'Bob': 79, 'Charlie': 100, 'David': 65, 'Peter': 95}
# {'Alice': 82, 'Bob': 79, 'Charlie': 100, 'Peter': 95}

# %%
# 30. Create a dictionary where keys are numbers 1-5 and values are their squares.
squares = {}
for i in range(1,6):
    squares[i] = i**2
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
